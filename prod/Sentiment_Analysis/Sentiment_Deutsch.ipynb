# %% [markdown]
# <H1>Sentiment Analyse Deutsch</H1>

# %%
import csv
import numpy as np
import pandas as pd
import re
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import datetime
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoModel
import torch
import emoji
import requests

# %%
df = pd.read_csv("/Users/tobias/Dev/FOM/Master_Thesis/data/Final_DE/Dataset_Wirecard.csv", sep=";",
                 parse_dates=["created_at"])

# %% [markdown]
# <h2>BERT Sentiment Analyse</h2>

# %%
#remove duplicate emojis
def remove_duplicate_emoji(orig_str):
    prev_emoji = None
    remove_duplicate_emoji = []
    for c in orig_str:
        if c in emoji.EMOJI_DATA:
            if prev_emoji == c:
                continue
            prev_emoji = c
        remove_duplicate_emoji.append(c)
    return "".join(remove_duplicate_emoji)

#remove all emojis
def de_emojify(text):
    regex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F" 
        u"\U0001F300-\U0001F5FF"
        u"\U0001F680-\U0001F6FF"
        u"\U0001F1E0-\U0001F1FF"
                           "]+", flags = re.UNICODE)
    return regex_pattern.sub(r'', text)

# %%
model_name = "oliverguhr/german-sentiment-bert"

model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
classifier(df.iloc[39]["text"])
# Out:
# [{'label': 'negative', 'score': 0.9396710395812988}]

# %%
emoji.demojize(df.iloc[39]["text"], language="de")
# Out:
# ' Freue mich drauf :süffisant_lächelndes_gesicht:'

# %%
classifier(emoji.demojize(df.iloc[39]["text"], language="de"))
# Out:
# [{'label': 'positive', 'score': 0.9853807091712952}]

# %%
#Zum Testen
for each in range(37400,37405):
    print(each)
    try:
        if len(emoji.demojize(df.iloc[each]["text"])) >= 425:
            print(each, " in if 1")
            if len(emoji.demojize(remove_duplicate_emoji(df.iloc[each]["text"]))) >= 425:
                print(each, " in if 2")
                if len(de_emojify(df.iloc[each]["text"])) >= 425:
                    print(each, " in if 3")
                    continue
                else:
                    print("Add ohne Emojis")
                    print(classifier(de_emojify(df.iloc[each]["text"]))[0]["label"])
            else:
                print("Add ohne doppelte Emojis")
                print(classifier(emoji.demojize(remove_duplicate_emoji(df.iloc[each]["text"])))[0]["label"])
        else:
            print("Add")
            print(classifier(emoji.demojize(df.iloc[each]["text"]))[0]["label"])
    except Exception:
        print(each, "neutral")

# %%
#Produktiv
list_sentiment_bert = []
list_error_tweets = []
n = 500
for each in range(len(df)):
    if (each/n) == 1:
        print(each)
        n = n + 500
    try:
        if len(emoji.demojize(df.iloc[each]["text"], language="de")) >= 425:
            if len(emoji.demojize(remove_duplicate_emoji(df.iloc[each]["text"]), language="de")) >= 425:
                if len(de_emojify(df.iloc[each]["text"])) >= 425:
                    continue
                else:
                    list_sentiment_bert.append(classifier(de_emojify(df.iloc[each]["text"]))[0]["label"])
            else:
                list_sentiment_bert.append(classifier(emoji.demojize(remove_duplicate_emoji(df.iloc[each]["text"]), language="de"))[0]["label"])
        else:
            list_sentiment_bert.append(classifier(emoji.demojize(df.iloc[each]["text"], language="de"))[0]["label"])
    except Exception:
        print(each)
        list_sentiment_bert.append("neutral")
        list_error_tweets.append(each)
# Out:
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000
# 23500
# 24000
# 24500
# 25000
# 25500
# 26000
# 26500
# 27000
# 27500
# 28000
# 28500
# 29000
# 29500
# 30000
# 30500
# 31000
# 31500
# 32000
# 32500
# 33000
# 33500
# 34000
# 34500
# 35000
# 35500
# 36000
# 36500
# 37000
# 37500
# 38000
# 38500
# 39000
# 39500
# 40000
# 40500
# 41000
# 41500
# 42000
# 42500
# 43000
# 43500
# 44000
# 44500
# 45000
# 45500
# 46000
# 46500
# 47000
# 47500
# 48000
# 48500
# 49000
# 49500
# 50000
# 50500
# 51000
# 51500
# 52000
# 52500
# 53000
# 53500
# 54000
# 54500
# 55000
# 55500
# 56000
# 56500
# 57000
# 57500
# 58000
# 58500
# 59000
# 59500
# 60000
# 60500
# 61000
# 61500
# 62000
# 62500
# 63000
# 63500
# 64000
# 64500
# 65000
# 65500
# 66000
# 66500
# 67000
# 67500
# 68000
# 68500
# 69000
# 69500
# 70000
# 70500
# 71000
# 71500
# 72000
# 72500
# 73000
# 73500
# 74000
# 74500
# 75000
# 75500
# 76000
# 76500
# 77000
# 77500
# 78000
# 78500
# 79000
# 79500
# 80000
# 80500
# 81000
# 81500
# 82000
# 82500
# 83000
# 83500
# 84000
# 84500
# 85000
# 85500
# 86000
# 86500
# 87000
# 87500
# 88000
# 88500
# 89000
# 89500
# 90000
# 90500
# 91000
# 91500
# 92000
# 92500
# 93000
# 93500
# 94000
# 94500
# 95000
# 95500
# 96000
# 96500
# 97000
# 97500
# 98000
# 98500
# 99000
# 99500
# 100000
# 100500
# 101000
# 101500
# 102000
# 102500
# 103000
# 103500
# 104000
# 104500
# 105000
# 105500
# 106000
# 106500
# 107000
# 107500
# 108000
# 108500
# 109000
# 109500
# 110000
# 110500
# 111000
# 111500
# 112000
# 112500
# 113000
# 113500
# 114000

# %%
print(len(df))
print(len(list_sentiment_bert))
print(len(list_error_tweets))
# Out:
# 114444
# 114444
# 0

# %%
#Ergebnisse dem DF hinzufügen
df["sentiment_bert"] = list_sentiment_bert

# %%
df.head()
# Out:
#       conversation_id   author_id                created_at  \
# 0  703311366262800384  1392131804 2016-02-26 20:11:11+00:00
# 1  702405572012974080  1053723204 2016-02-24 08:11:53+00:00
# 2  700578193334411264    19811837 2016-02-19 07:10:32+00:00
# 3  700221272840601601    19811837 2016-02-18 07:32:15+00:00
# 4  697324084221227008   183289696 2016-02-10 07:39:51+00:00
#
#              tweet_id lang  retweet_count  reply_count  like_count  \
# 0  703311366262800384   de              0            0           2
# 1  702405572012974080   de              0            0           0
# 2  700578193334411264   de              2            0           0
# 3  700221272840601601   de              0            0           1
# 4  697324084221227008   de              0            0           0
#
#    quote_count              source tweet_type referenced_tweet_id  \
# 0            0  Twitter Web Client       None                None
# 1            0  Twitter Web Client       None                None
# 2            0  Twitter Web Client       None                None
# 3            0  Twitter Web Client       None                None
# 4            0             dlvr.it       None                None
#
#                                                 text sentiment_bert
# 0  Wirecard-Chef Markus Braun pumpt irrwitzige Su...        neutral
# 1  Jetzt günstig einsammeln und später absahnen? ...        neutral
# 2  Wirecard: Was führt der Vorstand im Schilde? M...        neutral
# 3  Wirecard-Vorstand kauft weiter massiv eigene A...       negative
# 4  📈 Wirecard: Serie von Aktienkäufen des Vorstan...        neutral

# %%
#Backup CSV erstellen
df.to_csv("Dataset_DE_Bert.csv", sep=";", index=False)

# %%
df_backup = df

# %% [markdown]
# <h2>GerVADER</h2>
# <p>Um GerVADER anzuwenden, musste ich das Projekt von <a href="https://github.com/KarstenAMF/GerVADER">GerVADER GitHub</a> herunterladen. <br> Das Projekt gibt klar an, wie die Datei strukturiert sein muss um das Programm auszuführen. Es muss sihc um eine TSV Datei handeln, bei der in der ersten Spalte die ID, in der zweiten (optional) eine Sentiment Wert und in der dritten der Text steht. <br>Das Skript führt einen durch die Anwendung. Es gibt zwei unterschieldiche Modi, hier musste der zweite genutzt werden. Es werden dann drei Datein erstellt, eine für die negativen, eine für die neutralen und eine für die positiven Texte. Leider geht dabei die ID verloren, weswegen der Merge mit dem ursprünglichen Datensatz über die Texte erfolgen muss.</p>

# %%
df_GerVADER = df[["tweet_id"]].copy()

# %%
df_GerVADER["label"] = ""

# %%
df_GerVADER.head()
# Out:
#              tweet_id label
# 0  703311366262800384
# 1  702405572012974080
# 2  700578193334411264
# 3  700221272840601601
# 4  697324084221227008

# %%
df_GerVADER["Sentence"] = df["text"]

# %%
df_GerVADER.head()
# Out:
#              tweet_id label                                           Sentence
# 0  703311366262800384        Wirecard-Chef Markus Braun pumpt irrwitzige Su...
# 1  702405572012974080        Jetzt günstig einsammeln und später absahnen? ...
# 2  700578193334411264        Wirecard: Was führt der Vorstand im Schilde? M...
# 3  700221272840601601        Wirecard-Vorstand kauft weiter massiv eigene A...
# 4  697324084221227008        📈 Wirecard: Serie von Aktienkäufen des Vorstan...

# %%
df_GerVADER = df_GerVADER.rename(columns={"tweet_id": "ID", "label": "Label"})

# %%
df_GerVADER.head()
# Out:
#                    ID Label                                           Sentence
# 0  703311366262800384        Wirecard-Chef Markus Braun pumpt irrwitzige Su...
# 1  702405572012974080        Jetzt günstig einsammeln und später absahnen? ...
# 2  700578193334411264        Wirecard: Was führt der Vorstand im Schilde? M...
# 3  700221272840601601        Wirecard-Vorstand kauft weiter massiv eigene A...
# 4  697324084221227008        📈 Wirecard: Serie von Aktienkäufen des Vorstan...

# %%
#Speichern der neuen TSV Datei für die Analyse mit GerVADER
df_GerVADER.to_csv("tweets.tsv", sep="\t", index=False, header=False)

# %%
#Einlesen und prüfen der Datei für die ngeativen Texte
df_GerVader_neg = pd.read_csv("/Users/tobias/Dev/FOM/Master_Thesis/tests/GerVADER-master/results/mode_All/31072022_115652/GERVADER__negative.tsv",
                              sep="\t",
                             names=["text", "tweet_id", "sentiment_GerVADER", "sentiment_GerVADER_detailed"])
df_GerVader_neg.head()
# Out:
#                                                 text  tweet_id  \
# 0  Auf Einladung von Bürgermeister Markus Braun d...       NaN
# 1   Wo kann man alte BRN-Beiträge hören? Wirecard...       NaN
# 2                     Markus du nervst so hart mann!       NaN
# 3   Man sollte sich überlegen, einen Englischkurs...       NaN
# 4    Wird halt nicht jeder als Elon geboren ... a...       NaN
#
#    sentiment_GerVADER                        sentiment_GerVADER_detailed
# 0             -0.2023  {'neg': 0.114, 'neu': 0.886, 'pos': 0.0, 'comp...
# 1             -0.2023  {'neg': 0.101, 'neu': 0.899, 'pos': 0.0, 'comp...
# 2             -0.5971  {'neg': 0.55, 'neu': 0.45, 'pos': 0.0, 'compou...
# 3             -0.1531  {'neg': 0.062, 'neu': 0.892, 'pos': 0.046, 'co...
# 4             -0.1027  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...

# %%
#Einlesen und prüfen der Datei für die neutralen Texte
df_GerVader_neu = pd.read_csv("/Users/tobias/Dev/FOM/Master_Thesis/tests/GerVADER-master/results/mode_All/31072022_115652/GERVADER__neutral.tsv",
                              sep="\t",
                             names=["text", "tweet_id", "sentiment_GerVADER", "sentiment_GerVADER_detailed"])
df_GerVader_neu.head()
# Out:
#                                                 text  tweet_id  \
# 0  Wirecard-Chef Markus Braun pumpt irrwitzige Su...       NaN
# 1  Wirecard-Vorstand kauft weiter massiv eigene A...       NaN
# 2  📈 Wirecard: Serie von Aktienkäufen des Vorstan...       NaN
# 3  Ein weiterer Goldsponsor der nativeadscamp ist...       NaN
# 4  Für Nerds wie  Wirecard AG's (WRCDF) CEO Marku...       NaN
#
#    sentiment_GerVADER                        sentiment_GerVADER_detailed
# 0                 0.0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1                 0.0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2                 0.0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3                 0.0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4                 0.0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...

# %%
#Einlesen und prüfen der Datei für die positiven Texte
df_GerVader_pos = pd.read_csv("/Users/tobias/Dev/FOM/Master_Thesis/tests/GerVADER-master/results/mode_All/31072022_115652/GERVADER_positive.tsv",
                              sep="\t",
                             names=["text", "tweet_id", "sentiment_GerVADER", "sentiment_GerVADER_detailed"])
df_GerVader_pos.head()
# Out:
#                                                 text  tweet_id  \
# 0  Jetzt günstig einsammeln und später absahnen? ...       NaN
# 1  Wirecard: Was führt der Vorstand im Schilde? M...       NaN
# 2     Im Wort Bunte steckt Braun in allen Schatti...       NaN
# 3  Wirecard-Aktie: Vorstandschef Braun sieht "seh...       NaN
# 4   Damn! Alle Hoffnungen ruhen jetzt auf Dr. Mar...       NaN
#
#    sentiment_GerVADER                        sentiment_GerVADER_detailed
# 0              0.4871  {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'comp...
# 1              0.3182  {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compou...
# 2              0.4588  {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'comp...
# 3              0.5256  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...
# 4              0.6467  {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'comp...

# %%
#Zusammenführen der drei Dateien
df_GerVader = pd.concat([df_GerVader_neg, df_GerVader_neu, df_GerVader_pos],ignore_index=True)

# %%
df_GerVader.head()
# Out:
#                                                 text  tweet_id  \
# 0  Auf Einladung von Bürgermeister Markus Braun d...       NaN
# 1   Wo kann man alte BRN-Beiträge hören? Wirecard...       NaN
# 2                     Markus du nervst so hart mann!       NaN
# 3   Man sollte sich überlegen, einen Englischkurs...       NaN
# 4    Wird halt nicht jeder als Elon geboren ... a...       NaN
#
#    sentiment_GerVADER                        sentiment_GerVADER_detailed
# 0             -0.2023  {'neg': 0.114, 'neu': 0.886, 'pos': 0.0, 'comp...
# 1             -0.2023  {'neg': 0.101, 'neu': 0.899, 'pos': 0.0, 'comp...
# 2             -0.5971  {'neg': 0.55, 'neu': 0.45, 'pos': 0.0, 'compou...
# 3             -0.1531  {'neg': 0.062, 'neu': 0.892, 'pos': 0.046, 'co...
# 4             -0.1027  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...

# %%
print(len(df_GerVader))
print(len(df))
# Out:
# 114444
# 114444

# %%
#Hinzufügen der Sentiment Werte aus den Dateien, anhand der übereinstimmung der Texte
list_error_tweets = []
n = 1000
for each in range(len(df_GerVader)):
    if (each/n) == 1:
        print(each)
        print("DF_1: ", df.loc[df["text"] == df_GerVader.iloc[each]["text"]].index[0])
        print("DF_1: ", df.iloc[df.loc[df["text"] == df_GerVader.iloc[each]["text"]].index[0]]["text"])
        print("DF_2: ", df_GerVader.loc[df_GerVader["text"] == (df.loc[df["text"] == df_GerVader.iloc[each]["text"]]["text"].iloc[0])]["sentiment_GerVADER"].iloc[0])
        print("DF_2: ", df_GerVader.loc[df_GerVader["text"] == (df.loc[df["text"] == df_GerVader.iloc[each]["text"]]["text"].iloc[0])]["text"].iloc[0]) 
        n = n + 1000
    try:
        df.at[df.loc[df["text"] == df_GerVader.iloc[each]["text"]].index[0], "sentiment_vader"] = df_GerVader.loc[df_GerVader["text"] == (df.loc[df["text"] == df_GerVader.iloc[each]["text"]]["text"].iloc[0])]["sentiment_GerVADER"].iloc[0]
        
    except Exception:
        print(each)
        list_error_tweets.append(df_GerVader.iloc[each]["text"])
# Out:
# 1000
# DF_1:  4333
# DF_1:     Aktie bis zum tot einfach shorten
# DF_2:  -0.4939
# DF_2:     Aktie bis zum tot einfach shorten
# 2000
# DF_1:  7587
# DF_1:  Jan Marsalek hat den Finanzdienstleister Wirecard mitgeprägt bis zu seiner fristlosen Entlassung. Seither wird er gesucht. Nun führt eine Spur nach Weißrussland.
# DF_2:  -0.1027
# DF_2:  Jan Marsalek hat den Finanzdienstleister Wirecard mitgeprägt bis zu seiner fristlosen Entlassung. Seither wird er gesucht. Nun führt eine Spur nach Weißrussland.
# 3000
# DF_1:  14558
# DF_1:  TecDax: SMA schwindet ++ Wirecard abwärts ++ Telefonica zieht an ++ Siltronic vorneweg ++ TecDax erhöht Verlust
# DF_2:  -0.6705
# DF_2:  TecDax: SMA schwindet ++ Wirecard abwärts ++ Telefonica zieht an ++ Siltronic vorneweg ++ TecDax erhöht Verlust
# 4000
# DF_1:  11880
# DF_1:  🔍 Wirecard Technologies GmbH sucht Developer Java (m/f) Division Issuing 🔎Jobs München
# DF_2:  -0.4588
# DF_2:  🔍 Wirecard Technologies GmbH sucht Developer Java (m/f) Division Issuing 🔎Jobs München
# 5000
# DF_1:  26001
# DF_1:  Die kleine Presseschau  vom 29. August 2018 mit Amazon Google Facebook AstonMartin IPO Commerzbank Ferrari Oldtimer Sachwerte  EZB Fed Inflation Geldpolitik GoldmanSachs RTL TecDAX TeleColumbus Voestalpine Wirecard Xing
# DF_2:  -0.4215
# DF_2:  Die kleine Presseschau  vom 29. August 2018 mit Amazon Google Facebook AstonMartin IPO Commerzbank Ferrari Oldtimer Sachwerte  EZB Fed Inflation Geldpolitik GoldmanSachs RTL TecDAX TeleColumbus Voestalpine Wirecard Xing
# 6000
# DF_1:  33173
# DF_1:  AKTIE IM FOKUS: Bericht über Untersuchung von Geldströmen belastet Wirecard -
# DF_2:  -0.3182
# DF_2:  AKTIE IM FOKUS: Bericht über Untersuchung von Geldströmen belastet Wirecard -
# 7000
# DF_1:  37518
# DF_1:  TecDax: Siltronic knickt ein ++ Telefónica Deutschland gedrückt ++ Wirecard erneut Schlußlicht ++ S&amp;T schwach ++ TecDax unter 2.500 Punkten
# DF_2:  -0.4019
# DF_2:  TecDax: Siltronic knickt ein ++ Telefónica Deutschland gedrückt ++ Wirecard erneut Schlußlicht ++ S&amp;T schwach ++ TecDax unter 2.500 Punkten
# 8000
# DF_1:  40967
# DF_1:  Unser  hat zusammen mit  die internen Unterlagen der BaFin zu Wirecard gesichtet. Die Ergebnisse drüben bei
# DF_2:  -0.296
# DF_2:  Unser  hat zusammen mit  die internen Unterlagen der BaFin zu Wirecard gesichtet. Die Ergebnisse drüben bei
# 9000
# DF_1:  45995
# DF_1:  Börse: Wirecard-Aktie führt schwachen Dax an  via
# DF_2:  -0.1027
# DF_2:  Börse: Wirecard-Aktie führt schwachen Dax an  via
# 10000
# DF_1:  52477
# DF_1:    Das war wohl das mit dem „T“. Ansonsten vermute ich „ief_auchen“ ins Geschehen. Aber dass die Fernbedienung der F_-Rep_iloiden über Merkel hinaus nun auch bis zur Wirecard-Webseite reich_, mach_ mir Sorgen. Es verschwinden ja jetz_ auch „T“-Buchs_aben.
# DF_2:  -0.3818
# DF_2:    Das war wohl das mit dem „T“. Ansonsten vermute ich „ief_auchen“ ins Geschehen. Aber dass die Fernbedienung der F_-Rep_iloiden über Merkel hinaus nun auch bis zur Wirecard-Webseite reich_, mach_ mir Sorgen. Es verschwinden ja jetz_ auch „T“-Buchs_aben.
# 11000
# DF_1:  58441
# DF_1:  Wirecard Bilanzskandal? Nichts als heiße Luft  via
# DF_2:  -0.3412
# DF_2:  Wirecard Bilanzskandal? Nichts als heiße Luft  via
# 12000
# DF_1:  63268
# DF_1:  ⁦ : Wirecard und KPMG ringen um Formulierungen. Prüfer hätten negative Feststellungen zur Compliance und den internen Prozessen getroffen.
# DF_2:  -0.4588
# DF_2:  ⁦ : Wirecard und KPMG ringen um Formulierungen. Prüfer hätten negative Feststellungen zur Compliance und den internen Prozessen getroffen.
# 13000
# DF_1:  68035
# DF_1:    Wirecard  das "equal weight" bedeutet nichts anderes als eine von Analysten gewählte "stand by position" durch die Tatsache geschuldet, dass das Ergebnis 2019 und Q1 / 20 noch nicht veröffentlicht wurde. Völlig undramatisch
# DF_2:  -0.1027
# DF_2:    Wirecard  das "equal weight" bedeutet nichts anderes als eine von Analysten gewählte "stand by position" durch die Tatsache geschuldet, dass das Ergebnis 2019 und Q1 / 20 noch nicht veröffentlicht wurde. Völlig undramatisch
# 14000
# DF_1:  71486
# DF_1:  Wirecard :: WIRECARDIn 2 Monaten von 140 EUR auf 1.40 EUR. Verständlich, dass der Bilanz Teil in meinem Studium so stark gewichtet ist, wenn ein Bilanz Skandal ein Unternehmen so gewaltig erschüttern kann.
# DF_2:  -0.2911
# DF_2:  Wirecard :: WIRECARDIn 2 Monaten von 140 EUR auf 1.40 EUR. Verständlich, dass der Bilanz Teil in meinem Studium so stark gewichtet ist, wenn ein Bilanz Skandal ein Unternehmen so gewaltig erschüttern kann.
# 15000
# DF_1:  74871
# DF_1:  Erst betrügen und dann das. 😡
# DF_2:  -0.3182
# DF_2:  Erst betrügen und dann das. 😡
# 16000
# DF_1:  78247
# DF_1:  ➦ Kunden wenden sich von Wirecard ab - FAZ - Frankfurter Allgemeine Zeitung» Kunden wenden sich von Wirecard ab  FAZ - Frankfurter Allgemeine ZeitungBilanzskandal: Wirecard wird zum Problem für die Bundesregierung  Handelsblatt Aufseher ohne Zähne
# DF_2:  -0.2732
# DF_2:  ➦ Kunden wenden sich von Wirecard ab - FAZ - Frankfurter Allgemeine Zeitung» Kunden wenden sich von Wirecard ab  FAZ - Frankfurter Allgemeine ZeitungBilanzskandal: Wirecard wird zum Problem für die Bundesregierung  Handelsblatt Aufseher ohne Zähne
# 17000
# DF_1:  81750
# DF_1:      So sieht leider die Realität aus. Von wegen breit gestreut
# DF_2:  -0.4549
# DF_2:      So sieht leider die Realität aus. Von wegen breit gestreut
# 18000
# DF_1:  85378
# DF_1:  ➦ Dax schließt im Plus – Wirecard-Drama geht weiter - Handelsblatt» Dax schließt im Plus – Wirecard-Drama geht weiter  Handelsblatt Der Börsen-Tag:17:41 Dax am Hexensabbat mit Gewinn - Wirecard brennt weiter  n-tv NACHRICHTENDAX-Check: Der Tag
# DF_2:  -0.128
# DF_2:  ➦ Dax schließt im Plus – Wirecard-Drama geht weiter - Handelsblatt» Dax schließt im Plus – Wirecard-Drama geht weiter  Handelsblatt Der Börsen-Tag:17:41 Dax am Hexensabbat mit Gewinn - Wirecard brennt weiter  n-tv NACHRICHTENDAX-Check: Der Tag
# 19000
# DF_1:  88666
# DF_1:    bin mir nicht sicher, ob Herr Braun den Aktionären noch viel erklären wird...
# DF_2:  -0.2755
# DF_2:    bin mir nicht sicher, ob Herr Braun den Aktionären noch viel erklären wird...
# 20000
# DF_1:  92402
# DF_1:  Die Staatsanwaltschaft München hat nach einer Strafanzeige durch die Bundesanstalt für Finanzdienstleistungsaufsicht BaFin ein Verfahren gegen den Vorstand von Wirecard wegen des Verdachts der Marktmanipulation eingeleitet.
# DF_2:  -0.2732
# DF_2:  Die Staatsanwaltschaft München hat nach einer Strafanzeige durch die Bundesanstalt für Finanzdienstleistungsaufsicht BaFin ein Verfahren gegen den Vorstand von Wirecard wegen des Verdachts der Marktmanipulation eingeleitet.
# 21000
# DF_1:  95864
# DF_1:  Wenn es wirklich um Aufklärung geht  bei Wirecard, warum spielt dann Exekutivdirektor Bankenaufsicht Raimund Röseler keine Rolle bei Suche nach Verfehlungen? Und was ist mit d Referatsleitern?Hufeld trägt Gesamtverantwortung, aber alles auf ihn zu fokussieren nicht sachdienlich
# DF_2:  -0.4515
# DF_2:  Wenn es wirklich um Aufklärung geht  bei Wirecard, warum spielt dann Exekutivdirektor Bankenaufsicht Raimund Röseler keine Rolle bei Suche nach Verfehlungen? Und was ist mit d Referatsleitern?Hufeld trägt Gesamtverantwortung, aber alles auf ihn zu fokussieren nicht sachdienlich
# 22000
# DF_1:  99152
# DF_1:  Wirecard: SPÖ setzt Kurz unter Druck
# DF_2:  -0.1531
# DF_2:  Wirecard: SPÖ setzt Kurz unter Druck
# 23000
# DF_1:  102639
# DF_1:  Bilanzbetrug ist in Europäischen Unternehmen kein Zufall. Lehmann BrothersDeutsche BankCommerzbankPorscheVolkswagenWirecardSchäfflers GruppeContinentaleSiemensDBUniCreditSwissLufthansaAir FranceShell....................sollten alle ernsthaft geprüft werden.
# DF_2:  -0.128
# DF_2:  Bilanzbetrug ist in Europäischen Unternehmen kein Zufall. Lehmann BrothersDeutsche BankCommerzbankPorscheVolkswagenWirecardSchäfflers GruppeContinentaleSiemensDBUniCreditSwissLufthansaAir FranceShell....................sollten alle ernsthaft geprüft werden.
# 24000
# DF_1:  105917
# DF_1:  2/x Dieser FDP-Account wurde gehackt und ist schon seit längerem unter der Kontrolle von Finanzbetrügern. STORY HAUS bemüht sich, wieder Zugang zu bekommen. Niemals sollte er Einsicht in heikle Angelegenheiten wie wirecard bekommen. Vorsicht!
# DF_2:  -0.2244
# DF_2:  2/x Dieser FDP-Account wurde gehackt und ist schon seit längerem unter der Kontrolle von Finanzbetrügern. STORY HAUS bemüht sich, wieder Zugang zu bekommen. Niemals sollte er Einsicht in heikle Angelegenheiten wie wirecard bekommen. Vorsicht!
# 25000
# DF_1:  109521
# DF_1:  Wirecard - Das Versagen der Aufseher und Prüfer
# DF_2:  -0.4767
# DF_2:  Wirecard - Das Versagen der Aufseher und Prüfer
# 26000
# DF_1:  112941
# DF_1:  CEO braun gegen kaution freigelassen,dann fristlos von wirecard gekündigt,aber es sind wohl noch andere in das chaos verwickelt.alledings ist umklar warum die staatsanwaltschaft gegen die frühen warner vorginganstatt damals genauer hinzugucken  2/2
# DF_2:  -0.2263
# DF_2:  CEO braun gegen kaution freigelassen,dann fristlos von wirecard gekündigt,aber es sind wohl noch andere in das chaos verwickelt.alledings ist umklar warum die staatsanwaltschaft gegen die frühen warner vorginganstatt damals genauer hinzugucken  2/2
# 27000
# DF_1:  2182
# DF_1:     Hmm, wirklich schade.Vielleicht kommt jetzt ein anderes Unternehmen und schluckt Wirecard. Hab sowas in der Richtung schon gelesen heute
# DF_2:  0.0
# DF_2:     Hmm, wirklich schade.Vielleicht kommt jetzt ein anderes Unternehmen und schluckt Wirecard. Hab sowas in der Richtung schon gelesen heute
# 28000
# DF_1:  5601
# DF_1:  Wirecard-Chef Markus Braun tritt mit sofortiger Wirkung zurück - via
# DF_2:  0.0
# DF_2:  Wirecard-Chef Markus Braun tritt mit sofortiger Wirkung zurück - via
# 29000
# DF_1:  8874
# DF_1:  Startup-Partnerbank: Wie eine dubioser Report die Wirecard-Aktie in den Keller schickte: Eigentlich war die Ak...
# DF_2:  0.0
# DF_2:  Startup-Partnerbank: Wie eine dubioser Report die Wirecard-Aktie in den Keller schickte: Eigentlich war die Ak...
# 30000
# DF_1:  11553
# DF_1:   Getränke, 2 Brezeln und Thunfischsalat hehe, auf Kosten von WireCard
# DF_2:  0.0
# DF_2:   Getränke, 2 Brezeln und Thunfischsalat hehe, auf Kosten von WireCard
# 31000
# DF_1:  14331
# DF_1:  Wirecard: Mit wehenden Fahnen in die Zukunft -
# DF_2:  0.0
# DF_2:  Wirecard: Mit wehenden Fahnen in die Zukunft -
# 32000
# DF_1:  17768
# DF_1:  Wirecard-Aktie markiert Rekordhoch - Aktienanalyse - AktienCheck
# DF_2:  0.0
# DF_2:  Wirecard-Aktie markiert Rekordhoch - Aktienanalyse - AktienCheck
# 33000
# DF_1:  21245
# DF_1:  PM: Dank Wirecard wird die Retail-Tochter eurotrade des Flughafen Münc ...
# DF_2:  0.0
# DF_2:  PM: Dank Wirecard wird die Retail-Tochter eurotrade des Flughafen Münc ...
# 34000
# DF_1:  24817
# DF_1:  📝 AKTIE IM FOKUS: Wirecard steuert auf 12. Gewinntag in Folge zu  ❚BÖRSE FFM
# DF_2:  0.0
# DF_2:  📝 AKTIE IM FOKUS: Wirecard steuert auf 12. Gewinntag in Folge zu  ❚BÖRSE FFM
# 35000
# DF_1:  28259
# DF_1:  Wirecard mausert sich zum Star der deutschen Finanzbranche. Jetzt lesen:
# DF_2:  0.0
# DF_2:  Wirecard mausert sich zum Star der deutschen Finanzbranche. Jetzt lesen:
# 36000
# DF_1:  31623
# DF_1:  Zahlungsabwickler: Wirecard erhöht erneut sein Gewinnziel...
# DF_2:  -0.0258
# DF_2:  Zahlungsabwickler: Wirecard erhöht erneut sein Gewinnziel...
# 37000
# DF_1:  34332
# DF_1:          Also Dein Ansatz ist dann die Sparkassen App als Multibanking Center auszubauen, dort die Mehrwerte darzustellen und irgendwann das Girokonto dahinter still zu legen?
# DF_2:  0.0
# DF_2:          Also Dein Ansatz ist dann die Sparkassen App als Multibanking Center auszubauen, dort die Mehrwerte darzustellen und irgendwann das Girokonto dahinter still zu legen?
# 38000
# DF_1:  37409
# DF_1:  Wirecard: Warum erst jetzt? - Der Aktionär politik wirtschaft
# DF_2:  0.0
# DF_2:  Wirecard: Warum erst jetzt? - Der Aktionär politik wirtschaft
# 39000
# DF_1:  40670
# DF_1:  Most Actives: Wirecard, Deutsche Bank und Deutsche Telekom; mehr in dieser Sendung:
# DF_2:  0.0
# DF_2:  Most Actives: Wirecard, Deutsche Bank und Deutsche Telekom; mehr in dieser Sendung:
# 40000
# DF_1:  43802
# DF_1:  Auf fallende Kurse bei Wirecard konnte seit Februar nicht gewettet werden. Nun hat die Börsenaufsicht Bafin das Leerverkaufsverbot aufgehoben.
# DF_2:  0.0
# DF_2:  Auf fallende Kurse bei Wirecard konnte seit Februar nicht gewettet werden. Nun hat die Börsenaufsicht Bafin das Leerverkaufsverbot aufgehoben.
# 41000
# DF_1:  46796
# DF_1:  Wirecard: Das Kursplus ist zu wenig
# DF_2:  0.0
# DF_2:  Wirecard: Das Kursplus ist zu wenig
# 42000
# DF_1:  49774
# DF_1:  TecDax: Wirecard gedrückt ++ S&amp;T Schlußlicht ++ Compugroup ohne Halt ++ Nordex flügellahm ++ TecDax gibt nach
# DF_2:  0.0
# DF_2:  TecDax: Wirecard gedrückt ++ S&amp;T Schlußlicht ++ Compugroup ohne Halt ++ Nordex flügellahm ++ TecDax gibt nach
# 43000
# DF_1:  52846
# DF_1:     Nicht für Wirecard?
# DF_2:  0.0
# DF_2:     Nicht für Wirecard?
# 44000
# DF_1:  55913
# DF_1:  Eine Firma, die dementieren muss, ihre Widersacher auszuforschen, ist in einer misslichen Lage. Wirecard - Unter Wölfen (via
# DF_2:  0.0
# DF_2:  Eine Firma, die dementieren muss, ihre Widersacher auszuforschen, ist in einer misslichen Lage. Wirecard - Unter Wölfen (via
# 45000
# DF_1:  58999
# DF_1:  Mensch, Wirecard-Investoren: Lasst euch nicht vom Gerichtstermin-Wirrwarr blenden! -
# DF_2:  0.0
# DF_2:  Mensch, Wirecard-Investoren: Lasst euch nicht vom Gerichtstermin-Wirrwarr blenden! -
# 46000
# DF_1:  62154
# DF_1:  Wenn ich mir ansehe, was heute mit der Wirecard Aktie abgeht... dann steht der gestrige Flash-Crash auf 106 Euro plötzlich in einem ganz anderen Licht...
# DF_2:  0.0
# DF_2:  Wenn ich mir ansehe, was heute mit der Wirecard Aktie abgeht... dann steht der gestrige Flash-Crash auf 106 Euro plötzlich in einem ganz anderen Licht...
# 47000
# DF_1:  64963
# DF_1:  Diese Woche im FOCUS:&gt; Madame Oui: Angela Merkels europäisches Vermächtnis.&gt; Wirecard: Ein bayerisches Börsendrama.&gt; Der Büchermensch: 100 Jahre Marcel Reich-Ranicki.Mehr Menschen, mehr Geschichten, mehr Fakten unter:
# DF_2:  0.0
# DF_2:  Diese Woche im FOCUS:&gt; Madame Oui: Angela Merkels europäisches Vermächtnis.&gt; Wirecard: Ein bayerisches Börsendrama.&gt; Der Büchermensch: 100 Jahre Marcel Reich-Ranicki.Mehr Menschen, mehr Geschichten, mehr Fakten unter:
# 48000
# DF_1:  68176
# DF_1:  Die Deutsche Börse leitet ein Verwaltungsverfahren gegen Wirecard ein. Weiß jemand, ob dieses ggf. öffentlich ist??
# DF_2:  0.0
# DF_2:  Die Deutsche Börse leitet ein Verwaltungsverfahren gegen Wirecard ein. Weiß jemand, ob dieses ggf. öffentlich ist??
# 49000
# DF_1:  71340
# DF_1:  Ich bin verwirrt... 😁Wirecard  boon
# DF_2:  0.0
# DF_2:  Ich bin verwirrt... 😁Wirecard  boon
# 50000
# DF_1:  74377
# DF_1:  Bin ich der einzige, der von Wirecard bis vor 1 Woche noch nie was gehört hat?
# DF_2:  0.0
# DF_2:  Bin ich der einzige, der von Wirecard bis vor 1 Woche noch nie was gehört hat?
# 51000
# DF_1:  185
# DF_1:  Kannste dir nicht ausdenken.
# DF_2:  0.0
# DF_2:  Kannste dir nicht ausdenken.
# 52000
# DF_1:  4542
# DF_1:  Ex-Wirecard-Chef Braun festgenommen
# DF_2:  0.0
# DF_2:  Ex-Wirecard-Chef Braun festgenommen
# 53000
# DF_1:  81881
# DF_1:  Wirecard: Konten über 1,9 Milliarden Euro gibt es wahrscheinlich nicht
# DF_2:  0.0
# DF_2:  Wirecard: Konten über 1,9 Milliarden Euro gibt es wahrscheinlich nicht
# 54000
# DF_1:  85958
# DF_1:  anstehendes Rating von Wirecard
# DF_2:  0.0
# DF_2:  anstehendes Rating von Wirecard
# 55000
# DF_1:  89066
# DF_1:   Bei Wirecard bricht das Kartenhaus endgültig zusammen. Wenn morgen Kredite über 2 Mrd € fällig gestellt werden weil das Testat über den Jahresabschluss fehlt wäre eine Insolvenz keine Überraschung. Ein Desaster für die Aktienkultur.
# DF_2:  -0.0237
# DF_2:   Bei Wirecard bricht das Kartenhaus endgültig zusammen. Wenn morgen Kredite über 2 Mrd € fällig gestellt werden weil das Testat über den Jahresabschluss fehlt wäre eine Insolvenz keine Überraschung. Ein Desaster für die Aktienkultur.
# 56000
# DF_1:  92399
# DF_1:  Der Schreiber hat absolut recht!Das ist ein Unding  Verwendet die Schlagzeilen an dem Tag , wenn sie zutreffen werden!ihr verschießt sonst jetzt schon euer Pulver.Konzentriert euch auf Razzia und die vermutete Marktmanipulation durch den wirecard Vorstand
# DF_2:  0.0
# DF_2:  Der Schreiber hat absolut recht!Das ist ein Unding  Verwendet die Schlagzeilen an dem Tag , wenn sie zutreffen werden!ihr verschießt sonst jetzt schon euer Pulver.Konzentriert euch auf Razzia und die vermutete Marktmanipulation durch den wirecard Vorstand
# 57000
# DF_1:  95362
# DF_1:   Man hätte auch gerne gewusst, was Schäuble damals unternommen hat.
# DF_2:  0.0
# DF_2:   Man hätte auch gerne gewusst, was Schäuble damals unternommen hat.
# 58000
# DF_1:  98227
# DF_1:  Vorstoß des Finanzministeriums: Diese Lehren zieht die Bundesregierung aus dem Fall Wirecard
# DF_2:  0.0
# DF_2:  Vorstoß des Finanzministeriums: Diese Lehren zieht die Bundesregierung aus dem Fall Wirecard
# 59000
# DF_1:  100924
# DF_1:  Wirecard: Finanzministerium informierte Kanzleramt über Ermittlungen gegen Dax-Konzern - DER SPIEGEL
# DF_2:  0.0
# DF_2:  Wirecard: Finanzministerium informierte Kanzleramt über Ermittlungen gegen Dax-Konzern - DER SPIEGEL
# 60000
# DF_1:  103690
# DF_1:  Wenn sich die These bewahrheitet, wird der Fall Wirecard endgültig zur epischen Blamage für BaFin, Finanzministerium, Kanzleramt, EY, und viele weitere Akteure.
# DF_2:  0.0
# DF_2:  Wenn sich die These bewahrheitet, wird der Fall Wirecard endgültig zur epischen Blamage für BaFin, Finanzministerium, Kanzleramt, EY, und viele weitere Akteure.
# 61000
# DF_1:  106497
# DF_1:  Die Bundesregierung mauert eigentlich ständig: Von der Leyen-BerateraffäreScheuer - Abgasskandal Scholz - CumEx Scheuer - MautScholz - Wirecard
# DF_2:  0.0
# DF_2:  Die Bundesregierung mauert eigentlich ständig: Von der Leyen-BerateraffäreScheuer - Abgasskandal Scholz - CumEx Scheuer - MautScholz - Wirecard
# 62000
# DF_1:  109325
# DF_1:  Andreas Scheuer - Wirecard der Bundesregierung
# DF_2:  0.0
# DF_2:  Andreas Scheuer - Wirecard der Bundesregierung
# 63000
# DF_1:  112619
# DF_1:  Bezahlen mit Bitcoin, Blockchain-Briefmarken und die Causa Wirecard
# DF_2:  0.0
# DF_2:  Bezahlen mit Bitcoin, Blockchain-Briefmarken und die Causa Wirecard
# 64000
# DF_1:  767
# DF_1:    Ausschließlich digitale Zahlungsprozesse ist das schlimmste, was uns für unsere Freiheit passieren kann.ProBargeld BargeldChallenge
# DF_2:  0.3818
# DF_2:    Ausschließlich digitale Zahlungsprozesse ist das schlimmste, was uns für unsere Freiheit passieren kann.ProBargeld BargeldChallenge
# 64746
# 65000
# DF_1:  2670
# DF_1:  Linksverdriftete haben eben keinen Humor!!
# DF_2:  0.5972
# DF_2:  Linksverdriftete haben eben keinen Humor!!
# 66000
# DF_1:  4997
# DF_1:      Wer sagt, dass du deine Finanzen offen legen sollst? Bestehen deine Finanzen nur aus Wirecard Aktien? Wenn du 120k€ Verlust hättest, würdest du nicht so erbärmlich über Twitter heulen, sondern einen Anwalt aufsuchen, du Taugenichts!
# DF_2:  0.401
# DF_2:      Wer sagt, dass du deine Finanzen offen legen sollst? Bestehen deine Finanzen nur aus Wirecard Aktien? Wenn du 120k€ Verlust hättest, würdest du nicht so erbärmlich über Twitter heulen, sondern einen Anwalt aufsuchen, du Taugenichts!
# 67000
# DF_1:  7423
# DF_1:   Über Jahre hat uns dieser Mann  belogen und betrogen.  die Partnerschaften alles Fake. Der größte Betrüger in der deutschen Börsengeschichte. Alle haben weggeschaut. Und  kauft sich jetzt mit unserem Geld frei in Wien.!!!!!!!!
# DF_2:  0.6083
# DF_2:   Über Jahre hat uns dieser Mann  belogen und betrogen.  die Partnerschaften alles Fake. Der größte Betrüger in der deutschen Börsengeschichte. Alle haben weggeschaut. Und  kauft sich jetzt mit unserem Geld frei in Wien.!!!!!!!!
# 68000
# DF_1:  9910
# DF_1:  Wirecard Aktie: Es bestätigt sich!
# DF_2:  0.3382
# DF_2:  Wirecard Aktie: Es bestätigt sich!
# 69000
# DF_1:  10624
# DF_1:  ▶ Exane BNP belässt Wirecard auf 'Outperform' - Ziel 50 Euro: PARIS (dpa-AFX Analyser) - Die…  AKTIENCHECK
# DF_2:  0.4019
# DF_2:  ▶ Exane BNP belässt Wirecard auf 'Outperform' - Ziel 50 Euro: PARIS (dpa-AFX Analyser) - Die…  AKTIENCHECK
# 70000
# DF_1:  13633
# DF_1:  ▶ Wirecard-Aktie: Management gibt sich optimistisch - Berenberg Bank rät zum Kauf - Aktienanalyse:…  AKTIENCHECKde
# DF_2:  0.5423
# DF_2:  ▶ Wirecard-Aktie: Management gibt sich optimistisch - Berenberg Bank rät zum Kauf - Aktienanalyse:…  AKTIENCHECKde
# 71000
# DF_1:  15321
# DF_1:  33 – MobileMonday Demo Night 2016 - powered by Wirecard CEE -   schaut euch die besten Smartphone Lösungen &amp; Serv...
# DF_2:  0.7506
# DF_2:  33 – MobileMonday Demo Night 2016 - powered by Wirecard CEE -   schaut euch die besten Smartphone Lösungen &amp; Serv...
# 72000
# DF_1:  17548
# DF_1:  ▶ Baader Bank belässt Wirecard auf 'Buy' - Ziel 70 Euro: MÜNCHEN (dpa-AFX Analyser) - Die Baader Bank…  AKTIENCHECK
# DF_2:  0.4019
# DF_2:  ▶ Baader Bank belässt Wirecard auf 'Buy' - Ziel 70 Euro: MÜNCHEN (dpa-AFX Analyser) - Die Baader Bank…  AKTIENCHECK
# 73000
# DF_1:  19574
# DF_1:  Wirecard bietet Händlern erweiterte globale Einblicke ins Payment und Risikomanagement  ots bot
# DF_2:  0.1779
# DF_2:  Wirecard bietet Händlern erweiterte globale Einblicke ins Payment und Risikomanagement  ots bot
# 74000
# DF_1:  21495
# DF_1:  PayTechTalk 11: Über den Weg vom Start-up zum internationalen Player, Mobile Payment in Deutschland und mehr (de) -
# DF_2:  0.25
# DF_2:  PayTechTalk 11: Über den Weg vom Start-up zum internationalen Player, Mobile Payment in Deutschland und mehr (de) -
# 75000
# DF_1:  23299
# DF_1:  ▶ ANALYSE-FLASH: Berenberg hebt Ziel für Wirecard auf 118 Euro - 'Buy': HAMBURG (dpa-AFX Broker) - Die Privatbank Berenberg hat das Kursziel für Wirecard von 98 auf 118 Euro angehoben und die Einstufung auf "Buy" belassen. Die…  FINANZTREFF
# DF_2:  0.4588
# DF_2:  ▶ ANALYSE-FLASH: Berenberg hebt Ziel für Wirecard auf 118 Euro - 'Buy': HAMBURG (dpa-AFX Broker) - Die Privatbank Berenberg hat das Kursziel für Wirecard von 98 auf 118 Euro angehoben und die Einstufung auf "Buy" belassen. Die…  FINANZTREFF
# 76000
# DF_1:  24899
# DF_1:  AKTIE IM FOKUS: Starkes Börsendebüt von Adyen treibt auch Wirecard voran -
# DF_2:  0.4404
# DF_2:  AKTIE IM FOKUS: Starkes Börsendebüt von Adyen treibt auch Wirecard voran -
# 77000
# DF_1:  26393
# DF_1:  Tech-Aktien: Sind Apple, Tesla und Wirecard wirklich ihre Rekordpreise wert?
# DF_2:  0.2263
# DF_2:  Tech-Aktien: Sind Apple, Tesla und Wirecard wirklich ihre Rekordpreise wert?
# 78000
# DF_1:  28072
# DF_1:  Wirecard: Die Aktie zeigt keine Schwäche! -
# DF_2:  0.416
# DF_2:  Wirecard: Die Aktie zeigt keine Schwäche! -
# 79000
# DF_1:  29813
# DF_1:  Wirecard gewinnt das KaDeWe, den Oberpollinger und das Alsterhaus als Kunden für Alipay-Zahlungen
# DF_2:  0.4939
# DF_2:  Wirecard gewinnt das KaDeWe, den Oberpollinger und das Alsterhaus als Kunden für Alipay-Zahlungen
# 80000
# DF_1:  31749
# DF_1:  📝 AKTIE IM FOKUS: Wirecard-Erholung geht weiter nach positiver Studie  ❚BÖRSE FFM
# DF_2:  0.4767
# DF_2:  📝 AKTIE IM FOKUS: Wirecard-Erholung geht weiter nach positiver Studie  ❚BÖRSE FFM
# 81000
# DF_1:  33774
# DF_1:  Der deutsche Zahlungsverkehrsabwickler Wirecard kriegt große Konkurrenz aus den USA. Dort übernimmt Fiserv seinen großen Rivalen First Data.
# DF_2:  0.1531
# DF_2:  Der deutsche Zahlungsverkehrsabwickler Wirecard kriegt große Konkurrenz aus den USA. Dort übernimmt Fiserv seinen großen Rivalen First Data.
# 82000
# DF_1:  36232
# DF_1:  OTS: Wirecard AG / Wirecard stellt mobile Payment-Lösung für Segmüller bereit ...
# DF_2:  0.4215
# DF_2:  OTS: Wirecard AG / Wirecard stellt mobile Payment-Lösung für Segmüller bereit ...
# 83000
# DF_1:  38895
# DF_1:  - Wirecard, Carl Zeiss Meditec und Pfeiffer Vacuum: Der TecDAX hat für diese Aktien aktuelle TrendsignaleDer TecDAX notiert mit 2534.67 Punkten aktuell (Stand 08:04 Uhr) im Plus (+0.84 Prozent).
# DF_2:  0.34
# DF_2:  - Wirecard, Carl Zeiss Meditec und Pfeiffer Vacuum: Der TecDAX hat für diese Aktien aktuelle TrendsignaleDer TecDAX notiert mit 2534.67 Punkten aktuell (Stand 08:04 Uhr) im Plus (+0.84 Prozent).
# 84000
# DF_1:  41212
# DF_1:  Jetzt lesen:   AKTIE IM FOKUS - Wirecard rutschen nach Pressebericht und Studie weiter ab aktuell /news/74241_252.html
# DF_2:  0.25
# DF_2:  Jetzt lesen:   AKTIE IM FOKUS - Wirecard rutschen nach Pressebericht und Studie weiter ab aktuell /news/74241_252.html
# 85000
# DF_1:  43327
# DF_1:  Wirecard: Softbank als neuer Partner in Fernost  / cashmagazin
# DF_2:  0.7184
# DF_2:  Wirecard: Softbank als neuer Partner in Fernost  / cashmagazin
# 86000
# DF_1:  45415
# DF_1:  Erstelle deinen eigenen Onlineshop mit SUPR by  Teste unsere komplette Funktionsvielfalt jetzt 30 Tage lang kostenlos und starte im ecommerce durch! 🤩
# DF_2:  0.6114
# DF_2:  Erstelle deinen eigenen Onlineshop mit SUPR by  Teste unsere komplette Funktionsvielfalt jetzt 30 Tage lang kostenlos und starte im ecommerce durch! 🤩
# 87000
# DF_1:  47296
# DF_1:  Wirecard: Wirecard treibt Smart Biometrics mit innovativem Handflächen-Scanner voran / Biometrie ist der nächste Bezahltrend mit vielen Einsatzszenarien darunter Veranstaltungen, Mobilität und im Einzelhandel
# DF_2:  0.7717
# DF_2:  Wirecard: Wirecard treibt Smart Biometrics mit innovativem Handflächen-Scanner voran / Biometrie ist der nächste Bezahltrend mit vielen Einsatzszenarien darunter Veranstaltungen, Mobilität und im Einzelhandel
# 88000
# DF_1:  49307
# DF_1:  Neu im BankÜberBlick * Innovationen haben es in Deutschland schwer* fintech startups mit psd2 Lizenz* milesandmore mit Banking app * digitaler Euro gegen Libra* wirecard mit neuem Service* KI in der Finanzbranche kostenlos abonnieren:
# DF_2:  0.8807
# DF_2:  Neu im BankÜberBlick * Innovationen haben es in Deutschland schwer* fintech startups mit psd2 Lizenz* milesandmore mit Banking app * digitaler Euro gegen Libra* wirecard mit neuem Service* KI in der Finanzbranche kostenlos abonnieren:
# 89000
# DF_1:  51129
# DF_1:  Der CEO von Wirecard, verbreitet digitalen Optimismus „wie damals die Elektrifizierung“
# DF_2:  0.5267
# DF_2:  Der CEO von Wirecard, verbreitet digitalen Optimismus „wie damals die Elektrifizierung“
# 90000
# DF_1:  53322
# DF_1:  Neuigkeit:   Aktie klettert an Dax-Spitze - „Vision 2025“ - Wirecard steckt Ziele ab - deutliche Umsatzsteigerung in Sicht news
# DF_2:  0.4588
# DF_2:  Neuigkeit:   Aktie klettert an Dax-Spitze - „Vision 2025“ - Wirecard steckt Ziele ab - deutliche Umsatzsteigerung in Sicht news
# 91000
# DF_1:  55196
# DF_1:  Prognosen für 2020 bekräftigt - Online-Boom lässt Gewinn von Wirecard um über 50 Prozent steigen
# DF_2:  0.7823
# DF_2:  Prognosen für 2020 bekräftigt - Online-Boom lässt Gewinn von Wirecard um über 50 Prozent steigen
# 92000
# DF_1:  57153
# DF_1:  Wirecard: Ein interessantes Detail - Aktie erholt sich
# DF_2:  0.7003
# DF_2:  Wirecard: Ein interessantes Detail - Aktie erholt sich
# 93000
# DF_1:  59105
# DF_1:  Wirecard's KPMG-Bericht kann eigentlich nicht richtig negativ sein, dagegen sprechen die Ad-hoc-Pflichten, strafbewehrt. tradingview investor TECDAX investment payment hedgefunds investing
# DF_2:  0.0762
# DF_2:  Wirecard's KPMG-Bericht kann eigentlich nicht richtig negativ sein, dagegen sprechen die Ad-hoc-Pflichten, strafbewehrt. tradingview investor TECDAX investment payment hedgefunds investing
# 94000
# DF_1:  61033
# DF_1:  Wirecard, TUI &amp; TFO: 3 einfache Investitionsthesen, über die Value-, Dividenden- und Wachstumsinvestoren nachdenken können!
# DF_2:  0.3802
# DF_2:  Wirecard, TUI &amp; TFO: 3 einfache Investitionsthesen, über die Value-, Dividenden- und Wachstumsinvestoren nachdenken können!
# 95000
# DF_1:  63457
# DF_1:    Nichts für schwache Nerven 😅 „Laut Insidern prüften die rund 40 KPMG-Experten auch noch zu Beginn dieser Woche einlaufende Zahlen von Drittpartnern.“
# DF_2:  0.5334
# DF_2:    Nichts für schwache Nerven 😅 „Laut Insidern prüften die rund 40 KPMG-Experten auch noch zu Beginn dieser Woche einlaufende Zahlen von Drittpartnern.“
# 96000
# DF_1:  65621
# DF_1:   na da bin ich gespannt..Die Eigentümerverhältnisse bei Al Alam sind deshalb so interessant, weil in Foren immer wieder gesagt gefragt wird "warum sollte Al Alam Geld an wirecard abführen, wenn Umsätze gefaked seinen"Nun ganz einfach.....es bleibt in/bei  der Family 😉
# DF_2:  0.4838
# DF_2:   na da bin ich gespannt..Die Eigentümerverhältnisse bei Al Alam sind deshalb so interessant, weil in Foren immer wieder gesagt gefragt wird "warum sollte Al Alam Geld an wirecard abführen, wenn Umsätze gefaked seinen"Nun ganz einfach.....es bleibt in/bei  der Family 😉
# 97000
# DF_1:  67755
# DF_1:  Wirecard ermöglicht der führenden türkischen Mineralwassermarke PINAR Water&amp;Beverages kontaktlose Zahlungen per App
# DF_2:  0.4404
# DF_2:  Wirecard ermöglicht der führenden türkischen Mineralwassermarke PINAR Water&amp;Beverages kontaktlose Zahlungen per App
# 98000
# DF_1:  70310
# DF_1:  "Meinen mehr als 100 Seiten langen Report schickte ich per Einschreiben an die BaFin, an Interpol, an Visa und Mastercard. Den Postbeleg habe ich aufbewahrt."Wirecard: „Die BaFin ignorierte jahrelang, was völlig offensichtlich war“ - FOCUS
# DF_2:  0.1513
# DF_2:  "Meinen mehr als 100 Seiten langen Report schickte ich per Einschreiben an die BaFin, an Interpol, an Visa und Mastercard. Den Postbeleg habe ich aufbewahrt."Wirecard: „Die BaFin ignorierte jahrelang, was völlig offensichtlich war“ - FOCUS
# 99000
# DF_1:  72867
# DF_1:  Eine im Spätkapitalismus, baby yeah! Wirecard
# DF_2:  0.3595
# DF_2:  Eine im Spätkapitalismus, baby yeah! Wirecard
# 100000
# DF_1:  75465
# DF_1:  angesichts der Entwicklung bei Wirecard muss man  für diese  sachliche und gute Analyse aus dem Jahr 2018 (noch) einmal Respekt zollen - lohnt sich noch einmal zu lesen:
# DF_2:  0.8271
# DF_2:  angesichts der Entwicklung bei Wirecard muss man  für diese  sachliche und gute Analyse aus dem Jahr 2018 (noch) einmal Respekt zollen - lohnt sich noch einmal zu lesen:
# 101000
# DF_1:  78398
# DF_1:   genau. nicht 100% in wirecard stecken, sondern auch mal nen 10er in enron.
# DF_2:  0.296
# DF_2:   genau. nicht 100% in wirecard stecken, sondern auch mal nen 10er in enron.
# 102000
# DF_1:  81214
# DF_1:   Schließlich würde die BaFin ja gegen die schlimmen Gerüchte vorgehen. Deutsche Politiker haben die BaFin ausdrücklich gelobt für die Ermittlungen gegen die FT. Natürlich hat das auch eine Signalfunktion für Kleinanleger. Und Fonds wie DWS waren heftig in Wirecard investiert. /2
# DF_2:  0.4019
# DF_2:   Schließlich würde die BaFin ja gegen die schlimmen Gerüchte vorgehen. Deutsche Politiker haben die BaFin ausdrücklich gelobt für die Ermittlungen gegen die FT. Natürlich hat das auch eine Signalfunktion für Kleinanleger. Und Fonds wie DWS waren heftig in Wirecard investiert. /2
# 103000
# DF_1:  83941
# DF_1:  Jetzt wird es richtig mysteriös. Wirecard Wo sind die Milliarden?
# DF_2:  0.3818
# DF_2:  Jetzt wird es richtig mysteriös. Wirecard Wo sind die Milliarden?
# 104000
# DF_1:  86426
# DF_1:  Hm wie könnte man nur digitale services günstig in die bank rein... 🤔wirecard
# DF_2:  0.4215
# DF_2:  Hm wie könnte man nur digitale services günstig in die bank rein... 🤔wirecard
# 105000
# DF_1:  89073
# DF_1:  Wer auch immer bei der  diesen Artikel über Wirecard geschrieben hat. Danke für so viel Shade 😂😂😂
# DF_2:  0.4404
# DF_2:  Wer auch immer bei der  diesen Artikel über Wirecard geschrieben hat. Danke für so viel Shade 😂😂😂
# 106000
# DF_1:  91516
# DF_1:  Wirecard reklamiert Interessenskonflikte beim Hackereport, aktuelle Shortstände, irgendwann wird operativ... aktien anlegen boerse boersen investment investieren trading KPMG investor invest Wirecard DAX payment FT fraud Hacker
# DF_2:  0.4588
# DF_2:  Wirecard reklamiert Interessenskonflikte beim Hackereport, aktuelle Shortstände, irgendwann wird operativ... aktien anlegen boerse boersen investment investieren trading KPMG investor invest Wirecard DAX payment FT fraud Hacker
# 107000
# DF_1:  93715
# DF_1:  ➦ Wirecard: Rasanter Aufstieg, tiefer Fall» Von unlauteren Machenschaften bei Wirecard wusste die ganze Branche – und die Politik.
# DF_2:  0.296
# DF_2:  ➦ Wirecard: Rasanter Aufstieg, tiefer Fall» Von unlauteren Machenschaften bei Wirecard wusste die ganze Branche – und die Politik.
# 108000
# DF_1:  96705
# DF_1:  Wenn man als Investor ein Management wiederholt fragt, wann es endlich Profit macht und man immer und immer wieder vertröstet wird, ist das ein unbefriedigendes Gefühl - und es vermengt sich nach der Wirecard Erfahrung mit einer ordentlichen Portion MißtrauenDeliveryHero DHER
# DF_2:  0.7506
# DF_2:  Wenn man als Investor ein Management wiederholt fragt, wann es endlich Profit macht und man immer und immer wieder vertröstet wird, ist das ein unbefriedigendes Gefühl - und es vermengt sich nach der Wirecard Erfahrung mit einer ordentlichen Portion MißtrauenDeliveryHero DHER
# 109000
# DF_1:  99453
# DF_1:  WIRECARD hat ALLE deutschen Kontroll-Organe  der Lächerlichkeit preisgegeben ‼️FAKT✅...und die Krone dieser Perversion wird sein: NIEMAND wird dafür zur Rechenschaft gezogen werden, obwohl die Ungereimtheiten seit Jahren bis ganz OBEN hin bekannt waren‼️ 🍌🆘🍌🆘🍌🆘🍌🆘🍌🆘
# DF_2:  0.3612
# DF_2:  WIRECARD hat ALLE deutschen Kontroll-Organe  der Lächerlichkeit preisgegeben ‼️FAKT✅...und die Krone dieser Perversion wird sein: NIEMAND wird dafür zur Rechenschaft gezogen werden, obwohl die Ungereimtheiten seit Jahren bis ganz OBEN hin bekannt waren‼️ 🍌🆘🍌🆘🍌🆘🍌🆘🍌🆘
# 110000
# DF_1:  102497
# DF_1:  Guten Morgen! Heute wichtig  EU-Gipfel zu Corona-Hilfen erneut verlängert. Opposition macht Druck auf Regierung wegen Wirecard. Beratungen in Frankfurt  nach der Krawallnacht. WHO-Forscherin optimistisch für Corona-Impfstoff. Niko Kovac übernimmt AS Monaco. (rom)
# DF_2:  0.8748
# DF_2:  Guten Morgen! Heute wichtig  EU-Gipfel zu Corona-Hilfen erneut verlängert. Opposition macht Druck auf Regierung wegen Wirecard. Beratungen in Frankfurt  nach der Krawallnacht. WHO-Forscherin optimistisch für Corona-Impfstoff. Niko Kovac übernimmt AS Monaco. (rom)
# 111000
# DF_1:  105336
# DF_1:  Warum läuft der Typ eigentlich noch frei rum? Den müsste man ja an sich schon für seine Extraportion Großherrenarroganz als Fuchs bei der Fuchsjagd einsetzen, aber inzwischen müsste der Herr Vonundzu wohl sogar für den Staatsanwalt interessant werden.
# DF_2:  0.6808
# DF_2:  Warum läuft der Typ eigentlich noch frei rum? Den müsste man ja an sich schon für seine Extraportion Großherrenarroganz als Fuchs bei der Fuchsjagd einsetzen, aber inzwischen müsste der Herr Vonundzu wohl sogar für den Staatsanwalt interessant werden.
# 112000
# DF_1:  108115
# DF_1:  Bild: JensSpahn beauftragte die Wirtschaftsprüfer von EY für 9,5 Mio.€ mit dem Masken-Controlling. Ohne Ausschreibung. Sicher eine gute Wahl, weil (h)EY, die haben schon bei Wirecard immer genau hingesehen. Ach, was ich mich noch frage: Wozu hat ein Ministerium Mitarbeiter?
# DF_2:  0.6111
# DF_2:  Bild: JensSpahn beauftragte die Wirtschaftsprüfer von EY für 9,5 Mio.€ mit dem Masken-Controlling. Ohne Ausschreibung. Sicher eine gute Wahl, weil (h)EY, die haben schon bei Wirecard immer genau hingesehen. Ach, was ich mich noch frage: Wozu hat ein Ministerium Mitarbeiter?
# 113000
# DF_1:  110776
# DF_1:  Das ist Symptombekämfung.  Es sollte verhindert werden, dass Wirecard und Dieselskandal überhaupt geschehen! Dann müssen Unternehmen nicht nur am Resultat (der Zahlen), sondern an der Wurzel, der Gesundheit der Organisation gemessen werden. Wollen das die Wirtschaftsprüfer?
# DF_2:  0.6239
# DF_2:  Das ist Symptombekämfung.  Es sollte verhindert werden, dass Wirecard und Dieselskandal überhaupt geschehen! Dann müssen Unternehmen nicht nur am Resultat (der Zahlen), sondern an der Wurzel, der Gesundheit der Organisation gemessen werden. Wollen das die Wirtschaftsprüfer?
# 114000
# DF_1:  113219
# DF_1:   Eine ITM Power, könnte in 20 Jahren deutlich mehr wert sein. Oder ein zock mit Wirecard.
# DF_2:  0.2911
# DF_2:   Eine ITM Power, könnte in 20 Jahren deutlich mehr wert sein. Oder ein zock mit Wirecard.

# %%
#Prüfen der fehlerhaften Ergebnisse
list_error_tweets[0]
# Out:
# ' Danke lieber Götz. Das frage ich mich seit gestern auch. Als Mitarbeiter im Rechnungswesen würde ich schnellstmöglich kündigen. Bin seit ca. 30 Jahren in diesem Bereich tätig.'

# %%
df.loc[df["text"].str.contains(list_error_tweets[0])]
# Out:
#           conversation_id            author_id                created_at  \
# 2187  1255139945586417666  1217881588882714625 2020-04-28 18:40:57+00:00
#
#                  tweet_id lang  retweet_count  reply_count  like_count  \
# 2187  1255205376909348864   de              0            0           1
#
#       quote_count               source  tweet_type  referenced_tweet_id  \
# 2187            0  Twitter for Android  replied_to  1255204204278358024
#
#                                                    text sentiment_bert  \
# 2187     Danke lieber Götz. Das frage ich mich seit ...       negative
#
#       sentiment_vader
# 2187          -0.4019

# %%
df_GerVader.loc[df_GerVader["text"] == list_error_tweets[0]]["sentiment_GerVADER"].iloc[0]
# Out:
# 0.6808

# %%
df.loc[df["text"].str.contains(list_error_tweets[0])].index[0]
# Out:
# 2187

# %%
#Hinzufügen des fehlerhaften Tweets
df.at[df.loc[df["text"].str.contains(list_error_tweets[0])].index[0], "sentiment_vader"] = df_GerVader.loc[df_GerVader["text"] == list_error_tweets[0]]["sentiment_GerVADER"].iloc[0]

# %%
df.loc[df["text"].str.contains(list_error_tweets[0])]
# Out:
#           conversation_id            author_id                created_at  \
# 2187  1255139945586417666  1217881588882714625 2020-04-28 18:40:57+00:00
#
#                  tweet_id lang  retweet_count  reply_count  like_count  \
# 2187  1255205376909348864   de              0            0           1
#
#       quote_count               source  tweet_type  referenced_tweet_id  \
# 2187            0  Twitter for Android  replied_to  1255204204278358024
#
#                                                    text sentiment_bert  \
# 2187     Danke lieber Götz. Das frage ich mich seit ...       negative
#
#       sentiment_vader
# 2187           0.6808

# %%
df.tail()
# Out:
#             conversation_id            author_id                created_at  \
# 114439  1164960547693105153           4584354895 2019-08-23 18:00:13+00:00
# 114440  1228994498610503680   704753138146877440 2020-02-17 17:53:29+00:00
# 114441  1228017316375539712  1138485557502382082 2020-02-13 18:09:16+00:00
# 114442  1275070899822059523           1001192245 2020-06-22 14:19:26+00:00
# 114443  1271435871364042754            392388185 2020-06-12 13:45:22+00:00
#
#                    tweet_id lang  retweet_count  reply_count  like_count  \
# 114439  1164960547693105153   de              0            0           0
# 114440  1229463896425205768   de              0            0           2
# 114441  1228018315785838593   de              0            0           0
# 114442  1275070899822059523   de              0            0           0
# 114443  1271438445500682244   de              0            1           9
#
#         quote_count              source  tweet_type  referenced_tweet_id  \
# 114439            0         tickwatcher        None                 None
# 114440            0     Twitter Web App  replied_to  1229459682403725314
# 114441            1  Twitter for iPhone  replied_to  1228017316375539712
# 114442            0      TalkMarketsApp        None                 None
# 114443            0     Twitter Web App  replied_to  1271435871364042754
#
#                                                      text sentiment_bert  \
# 114439  Top Gainers (&gt;30)UVXY JNUG DRIP OPYGY URR E...       negative
# 114440                   1/ Die Anwälte der Klägerseit...        neutral
# 114441  Ist nicht der WRCDF LV Anteil mit zusätzlichen...       negative
# 114442  Olaf Scholz - The German Finance Minister Is D...        neutral
# 114443   12.06. WDI              29,09 Mio.  +1,16% (v...       negative
#
#         sentiment_vader
# 114439           0.5574
# 114440           0.0000
# 114441           0.0000
# 114442           0.0000
# 114443           0.1027

# %%
df.head()
# Out:
#       conversation_id   author_id                created_at  \
# 0  703311366262800384  1392131804 2016-02-26 20:11:11+00:00
# 1  702405572012974080  1053723204 2016-02-24 08:11:53+00:00
# 2  700578193334411264    19811837 2016-02-19 07:10:32+00:00
# 3  700221272840601601    19811837 2016-02-18 07:32:15+00:00
# 4  697324084221227008   183289696 2016-02-10 07:39:51+00:00
#
#              tweet_id lang  retweet_count  reply_count  like_count  \
# 0  703311366262800384   de              0            0           2
# 1  702405572012974080   de              0            0           0
# 2  700578193334411264   de              2            0           0
# 3  700221272840601601   de              0            0           1
# 4  697324084221227008   de              0            0           0
#
#    quote_count              source tweet_type referenced_tweet_id  \
# 0            0  Twitter Web Client       None                None
# 1            0  Twitter Web Client       None                None
# 2            0  Twitter Web Client       None                None
# 3            0  Twitter Web Client       None                None
# 4            0             dlvr.it       None                None
#
#                                                 text sentiment_bert  \
# 0  Wirecard-Chef Markus Braun pumpt irrwitzige Su...        neutral
# 1  Jetzt günstig einsammeln und später absahnen? ...        neutral
# 2  Wirecard: Was führt der Vorstand im Schilde? M...        neutral
# 3  Wirecard-Vorstand kauft weiter massiv eigene A...       negative
# 4  📈 Wirecard: Serie von Aktienkäufen des Vorstan...        neutral
#
#    sentiment_vader
# 0          -0.2023
# 1          -0.2023
# 2          -0.5971
# 3          -0.1531
# 4          -0.1027

# %%
df["sentiment_vader"].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Dev/FOM/Master_Thesis/master_thesis_3.9.10/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/Dev/FOM/Master_Thesis/master_thesis_3.9.10/.venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Dev/FOM/Master_Thesis/master_thesis_3.9.10/.venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sentiment_vader'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df["sentiment_vader"]
#
# File ~/Dev/FOM/Master_Thesis/master_thesis_3.9.10/.venv/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/Dev/FOM/Master_Thesis/master_thesis_3.9.10/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'sentiment_vader'

# %%
df.loc[df["sentiment_vader"].notna()]["text"]
# Out:
# 114443     12.06. WDI              29,09 Mio.  +1,16% (v...
# Name: text, dtype: object

# %%
#Backup CSV erstellen
df.to_csv("Dataset_DE_Bert_VADER.csv", sep=";", index=False)
